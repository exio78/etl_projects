# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt

# Choose the data you want to extract.
indicators = ["DDOE01VEA086NWDB", "SLUEM1524ZSVEN"]

# Set the start and end dates for the data.
start_date = '2000-01-01'
end_date = '2023-03-08'

# Extract the data from FRED.
data = pdr.DataReader(indicators, 'fred', start_date, end_date)

# Print the data.
data.head()
# Out:
#             DDOE01VEA086NWDB  SLUEM1524ZSVEN
# DATE
# 2000-01-01           14.4610          23.874
# 2001-01-01           16.2371          22.213
# 2002-01-01           21.3055          27.067
# 2003-01-01           27.0759          28.144
# 2004-01-01           32.2705          25.822

# %%
plt.plot(data["SLUEM1524ZSVEN"])
plt.show()
